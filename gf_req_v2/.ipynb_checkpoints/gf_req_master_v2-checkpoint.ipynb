# %%
import pandas as pd
import datetime
import warnings
from gf_ck_gen import save_google_flights_landing
from gf_req import requests_get_with_playwright_cookies
from gf_parser import parse_google_flights_html_text

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', 30)
warnings.filterwarnings("ignore")

# %% [markdown]
# # Cookies Generation
#
# Esegui questa cella quando vuoi aggiornare/salvare nuovi cookies. Le celle successive useranno automaticamente gli ultimi cookies salvati in `gf_landing_artifacts`, senza passare `result["cookies_path"]`.

# %%
url = "https://www.google.com/travel/flights?gl=IT&hl=it&q=Flights%20to%20PMO%20from%20FCO%20on%202026-08-09%20oneway%20economy%20nonstops"
result = await save_google_flights_landing(url,headless=True,out_dir="gf_landing_artifacts",)
result
# Out:
# goto: https://www.google.com/travel/flights?gl=IT&hl=it&q=Flights%20to%20PMO%20from%20FCO%20on%202026-08-09%20oneway%20economy%20nonstops
# cookie banner clicked: True
# final url before save: https://www.google.com/travel/flights?gl=IT&hl=it&q=Flights+to+PMO+from+FCO+on+2026-08-09+oneway+economy+nonstops
# {
#   "input_url": "https://www.google.com/travel/flights?gl=IT&hl=it&q=Flights%20to%20PMO%20from%20FCO%20on%202026-08-09%20oneway%20economy%20nonstops",
#   "final_url": "https://www.google.com/travel/flights?gl=IT&hl=it&q=Flights+to+PMO+from+FCO+on+2026-08-09+oneway+economy+nonstops",
#   "cookie_banner_clicked": true,
#   "cookies_path": "gf_landing_artifacts/20260619_135101_cookies.json",
#   "cookies_count": 2,
#   "html_path": "gf_landing_artifacts/20260619_135101_landing.html",
#   "html_bytes": 2619710
# }
# {'input_url': 'https://www.google.com/travel/flights?gl=IT&hl=it&q=Flights%20to%20PMO%20from%20FCO%20on%202026-08-09%20oneway%20economy%20nonstops',
#  'final_url': 'https://www.google.com/travel/flights?gl=IT&hl=it&q=Flights+to+PMO+from+FCO+on+2026-08-09+oneway+economy+nonstops',
#  'cookie_banner_clicked': True,
#  'cookies_path': 'gf_landing_artifacts/20260619_135101_cookies.json',
#  'cookies_count': 2,
#  'html_path': 'gf_landing_artifacts/20260619_135101_landing.html',
#  'html_bytes': 2619710}

# %% [markdown]
# # Request Generation
#
# V2: `cookies_path` è opzionale. Se non viene passato, `gf_req` usa l’ultimo file `*_cookies.json` trovato in `gf_landing_artifacts`. L’output `out` contiene direttamente anche `out["html"]`, cioè `response.text`.

# %%
url = "https://www.google.com/travel/flights?gl=IT&hl=it&q=Flights%20from%20ROM%20to%20PMO%20on%202026-06-21%20oneway%20economy%20nonstops"
out = requests_get_with_playwright_cookies(url,out_html_path="gf_landing_artifacts/requests_get_response.html")

info={k: v for k, v in out.items() if k not in {"html", "response_text"}}
info
# Out:
# {'status_code': 200,
#  'ok': True,
#  'final_url': 'https://www.google.com/travel/flights?gl=IT&hl=it&q=Flights%20from%20ROM%20to%20PMO%20on%202026-06-21%20oneway%20economy%20nonstops',
#  'cookies_path': 'gf_landing_artifacts/20260619_135101_cookies.json',
#  'cookies_source': 'latest_saved',
#  'saved_path': 'gf_landing_artifacts/requests_get_response.html',
#  'response_bytes': 2388471,
#  'html_bytes': 2388471,
#  'content_type': 'text/html; charset=utf-8',
#  'encoding': 'utf-8'}

# %% [markdown]
# # Data Parser
#
# V2: il parser riceve direttamente l’HTML in memoria da `out["html"]`, senza leggere il file locale.

# %%
df, info = parse_google_flights_html_text(
    out["html"],
    include_raw_label=False,)

df.head()
# Out:
#    result_index flight_id             flight_id_source              section  \
# 0             0    XZ2717  travelimpactmodel_itinerary  Voli più pertinenti
# 1             3    XZ2711  travelimpactmodel_itinerary           Altri voli
# 2             1    AZ1783  travelimpactmodel_itinerary  Voli più pertinenti
# 3             4    AZ1789  travelimpactmodel_itinerary           Altri voli
# 4             5    XZ2715  travelimpactmodel_itinerary           Altri voli
#
#    price_eur currency     airline operated_by carrier_code flight_number  \
# 0         75      EUR  Aeroitalia        None           XZ          2717
# 1         90      EUR  Aeroitalia        None           XZ          2711
# 2         93      EUR         ITA        None           AZ          1783
# 3         93      EUR         ITA        None           AZ          1789
# 4        100      EUR  Aeroitalia        None           XZ          2715
#
#   flight_departure_date origin destination depart_time arrive_time  ...  \
# 0            2026-06-21    FCO         PMO       22:00       23:10  ...
# 1            2026-06-21    FCO         PMO       14:00       15:10  ...
# 2            2026-06-21    FCO         PMO       22:00       23:05  ...
# 3            2026-06-21    FCO         PMO       21:20       22:30  ...
# 4            2026-06-21    FCO         PMO       18:00       19:10  ...
#
#   stops_count                              origin_airport_name  \
# 0           0  Aeroporto di Roma - Fiumicino Leonardo da Vinci
# 1           0  Aeroporto di Roma - Fiumicino Leonardo da Vinci
# 2           0  Aeroporto di Roma - Fiumicino Leonardo da Vinci
# 3           0  Aeroporto di Roma - Fiumicino Leonardo da Vinci
# 4           0  Aeroporto di Roma - Fiumicino Leonardo da Vinci
#
#                     destination_airport_name      depart_day_text  \
# 0  Aeroporto di Palermo Falcone e Borsellino  domenica, giugno 21
# 1  Aeroporto di Palermo Falcone e Borsellino  domenica, giugno 21
# 2  Aeroporto di Palermo Falcone e Borsellino  domenica, giugno 21
# 3  Aeroporto di Palermo Falcone e Borsellino  domenica, giugno 21
# 4  Aeroporto di Palermo Falcone e Borsellino  domenica, giugno 21
#
#        arrive_day_text emissions_kg_co2e baggage_cabin_not_included  \
# 0  domenica, giugno 21              54.0                      False
# 1  domenica, giugno 21              54.0                      False
# 2  domenica, giugno 21              57.0                      False
# 3  domenica, giugno 21              56.0                      False
# 4  domenica, giugno 21              54.0                      False
#
#    flight_segments_count  flight_segment_ids             tim_itinerary  \
# 0                      1              XZ2717  FCO-PMO-XZ-2717-20260621
# 1                      1              XZ2711  FCO-PMO-XZ-2711-20260621
# 2                      1              AZ1783  FCO-PMO-AZ-1783-20260621
# 3                      1              AZ1789  FCO-PMO-AZ-1789-20260621
# 4                      1              XZ2715  FCO-PMO-XZ-2715-20260621
#
#                                travelimpactmodel_url card_id  \
# 0  https://www.travelimpactmodel.org/lookup/fligh...  QRCuqf
# 1  https://www.travelimpactmodel.org/lookup/fligh...  e7Puqc
# 2  https://www.travelimpactmodel.org/lookup/fligh...   cfRem
# 3  https://www.travelimpactmodel.org/lookup/fligh...  qdCkqd
# 4  https://www.travelimpactmodel.org/lookup/fligh...  XYiqHf
#
#   airport_codes_found                                         query_text  \
# 0             FCO,PMO  Flights from ROM to PMO on 2026-06-21 oneway e...
# 1             FCO,PMO  Flights from ROM to PMO on 2026-06-21 oneway e...
# 2             FCO,PMO  Flights from ROM to PMO on 2026-06-21 oneway e...
# 3             FCO,PMO  Flights from ROM to PMO on 2026-06-21 oneway e...
# 4             FCO,PMO  Flights from ROM to PMO on 2026-06-21 oneway e...
#
#                                 flight_segments_json
# 0  [{"origin": "FCO", "destination": "PMO", "carr...
# 1  [{"origin": "FCO", "destination": "PMO", "carr...
# 2  [{"origin": "FCO", "destination": "PMO", "carr...
# 3  [{"origin": "FCO", "destination": "PMO", "carr...
# 4  [{"origin": "FCO", "destination": "PMO", "carr...
#
# [5 rows x 32 columns]

# %% [markdown]
# # Plan Gen

# %%
def url_compose(city_dep,city_arr,target_date):
    return f"https://www.google.com/travel/flights?gl=IT&hl=it&q=Flights%20from%20{city_dep}%20to%20{city_arr}%20on%20{target_date}%20oneway%20economy%20nonstops"

def plan_gen(directory):
    plan_df=pd.read_excel(directory+"plan_sum26.xlsx")
    sigle_df=pd.read_excel(directory+"plan_sum26.xlsx",sheet_name='sigle')
    plan_df=pd.merge(plan_df,sigle_df.rename(columns={"city":"origin","sigla":"city_dep"}),on='origin')
    plan_df=pd.merge(plan_df,sigle_df.rename(columns={"city":"destination","sigla":"city_arr"}),on='destination')
    plan_df["url"]=plan_df.apply(lambda x:url_compose(x["city_dep"],x["city_arr"],x["target_date"]),axis=1)

    return plan_df

directory="plans/"
plan_df=plan_gen(directory)
plan_df.head()
# Out:
#     origin destination target_date cluster       flag city_dep city_arr  \
# 0  Alghero      Milano  2026-08-09    from  sum26_ext      AHO      MIL
# 1  Alghero      Milano  2026-08-16    from  sum26_ext      AHO      MIL
# 2  Alghero      Milano  2026-08-23    from  sum26_ext      AHO      MIL
# 3  Alghero      Milano  2026-08-30    from  sum26_ext      AHO      MIL
# 4  Alghero        Roma  2026-08-09    from  sum26_ext      AHO      ROM
#
#                                                  url
# 0  https://www.google.com/travel/flights?gl=IT&hl...
# 1  https://www.google.com/travel/flights?gl=IT&hl...
# 2  https://www.google.com/travel/flights?gl=IT&hl...
# 3  https://www.google.com/travel/flights?gl=IT&hl...
# 4  https://www.google.com/travel/flights?gl=IT&hl...

# %% [markdown]
# # Monitor Gen

# %%
def monitor_gen(plan_df):
    update_date=datetime.datetime.now().date()
    for row in plan_df.to_dict(orient='records'):
        print("-------------------------origin:",row["origin"],"destination:",row["destination"],"target_date:",row["target_date"])
        url=row["url"]
        out = requests_get_with_playwright_cookies(url,out_html_path="gf_landing_artifacts/requests_get_response.html")
        loc_df,info=parse_google_flights_html_text(out["html"],include_raw_label=False,)
        print("N. results:",len(loc_df))
        if len(loc_df)==0:
            break
        loc_df.to_excel(f"output/{str(update_date)}_{row['city_dep']}_{row['city_arr']}_{row['target_date']}.xlsx")

        
monitor_gen(plan_df.head())
# Out:
# -------------------------origin: Alghero destination: Milano target_date: 2026-08-09
# N. results: 5
#    result_index flight_id             flight_id_source              section  \
# 0             0    FR2255  travelimpactmodel_itinerary  Voli più pertinenti
# 1             1    AZ1569  travelimpactmodel_itinerary  Voli più pertinenti
# 2             2    FR1091  travelimpactmodel_itinerary  Voli più pertinenti
# 3             3    AZ1605  travelimpactmodel_itinerary           Altri voli
# 4             4    AZ1601  travelimpactmodel_itinerary           Altri voli
#
#    price_eur currency  airline operated_by carrier_code flight_number  \
# 0         29      EUR  Ryanair   Malta Air           FR          2255
# 1         55      EUR      ITA        None           AZ          1569
# 2         69      EUR  Ryanair   Malta Air           FR          1091
# 3        104      EUR      ITA        None           AZ          1605
# 4        104      EUR      ITA        None           AZ          1601
#
#   flight_departure_date origin destination depart_time arrive_time  ...  \
# 0            2026-08-09    AHO         BGY       07:35       08:50  ...
# 1            2026-08-09    AHO         LIN       07:00       08:10  ...
# 2            2026-08-09    AHO         MXP       17:35       18:50  ...
# 3            2026-08-09    AHO         LIN       08:55       10:05  ...
# 4            2026-08-09    AHO         LIN       20:55       22:05  ...
#
#   stops_count   origin_airport_name      destination_airport_name  \
# 0           0  Aeroporto di Alghero         Milan Bergamo Airport
# 1           0  Aeroporto di Alghero    Aeroporto di Milano Linate
# 2           0  Aeroporto di Alghero  Aeroporto di Milano Malpensa
# 3           0  Aeroporto di Alghero    Aeroporto di Milano Linate
# 4           0  Aeroporto di Alghero    Aeroporto di Milano Linate
#
#       depart_day_text     arrive_day_text emissions_kg_co2e  \
# 0  domenica, agosto 9  domenica, agosto 9              69.0
# 1  domenica, agosto 9  domenica, agosto 9              56.0
# 2  domenica, agosto 9  domenica, agosto 9              67.0
# 3  domenica, agosto 9  domenica, agosto 9              56.0
# 4  domenica, agosto 9  domenica, agosto 9              56.0
#
#   baggage_cabin_not_included  flight_segments_count  flight_segment_ids  \
# 0                       True                      1              FR2255
# 1                      False                      1              AZ1569
# 2                       True                      1              FR1091
# 3                      False                      1              AZ1605
# 4                      False                      1              AZ1601
#
#               tim_itinerary  \
# 0  AHO-BGY-FR-2255-20260809
# 1  AHO-LIN-AZ-1569-20260809
# 2  AHO-MXP-FR-1091-20260809
# 3  AHO-LIN-AZ-1605-20260809
# 4  AHO-LIN-AZ-1601-20260809
#
#                                travelimpactmodel_url card_id  \
# 0  https://www.travelimpactmodel.org/lookup/fligh...  IU86bf
# 1  https://www.travelimpactmodel.org/lookup/fligh...  QD5Pue
# 2  https://www.travelimpactmodel.org/lookup/fligh...   SAFWt
# 3  https://www.travelimpactmodel.org/lookup/fligh...  PnIUOe
# 4  https://www.travelimpactmodel.org/lookup/fligh...  kiutLb
#
#   airport_codes_found                                         query_text  \
# 0             AHO,BGY  Flights from AHO to MIL on 2026-08-09 oneway e...
# 1             AHO,LIN  Flights from AHO to MIL on 2026-08-09 oneway e...
# 2             AHO,MXP  Flights from AHO to MIL on 2026-08-09 oneway e...
# 3             AHO,LIN  Flights from AHO to MIL on 2026-08-09 oneway e...
# 4             AHO,LIN  Flights from AHO to MIL on 2026-08-09 oneway e...
#
#                                 flight_segments_json
# 0  [{"origin": "AHO", "destination": "BGY", "carr...
# 1  [{"origin": "AHO", "destination": "LIN", "carr...
# 2  [{"origin": "AHO", "destination": "MXP", "carr...
# 3  [{"origin": "AHO", "destination": "LIN", "carr...
# 4  [{"origin": "AHO", "destination": "LIN", "carr...
#
# [5 rows x 32 columns]
# -------------------------origin: Alghero destination: Milano target_date: 2026-08-16
# N. results: 5
#    result_index flight_id             flight_id_source              section  \
# 0             0    FR2255  travelimpactmodel_itinerary  Voli più pertinenti
# 1             1    FR1091  travelimpactmodel_itinerary  Voli più pertinenti
# 2             2    AZ1569  travelimpactmodel_itinerary  Voli più pertinenti
# 3             3    AZ1605  travelimpactmodel_itinerary           Altri voli
# 4             4    AZ1601  travelimpactmodel_itinerary           Altri voli
#
#    price_eur currency  airline operated_by carrier_code flight_number  \
# 0        121      EUR  Ryanair   Malta Air           FR          2255
# 1        145      EUR  Ryanair   Malta Air           FR          1091
# 2        164      EUR      ITA        None           AZ          1569
# 3        270      EUR      ITA        None           AZ          1605
# 4        270      EUR      ITA        None           AZ          1601
#
#   flight_departure_date origin destination depart_time arrive_time  ...  \
# 0            2026-08-16    AHO         BGY       07:35       08:50  ...
# 1            2026-08-16    AHO         MXP       17:35       18:50  ...
# 2            2026-08-16    AHO         LIN       07:00       08:10  ...
# 3            2026-08-16    AHO         LIN       08:55       10:05  ...
# 4            2026-08-16    AHO         LIN       20:55       22:05  ...
#
#   stops_count   origin_airport_name      destination_airport_name  \
# 0           0  Aeroporto di Alghero         Milan Bergamo Airport
# 1           0  Aeroporto di Alghero  Aeroporto di Milano Malpensa
# 2           0  Aeroporto di Alghero    Aeroporto di Milano Linate
# 3           0  Aeroporto di Alghero    Aeroporto di Milano Linate
# 4           0  Aeroporto di Alghero    Aeroporto di Milano Linate
#
#        depart_day_text      arrive_day_text emissions_kg_co2e  \
# 0  domenica, agosto 16  domenica, agosto 16              69.0
# 1  domenica, agosto 16  domenica, agosto 16              67.0
# 2  domenica, agosto 16  domenica, agosto 16              86.0
# 3  domenica, agosto 16  domenica, agosto 16              86.0
# 4  domenica, agosto 16  domenica, agosto 16              56.0
#
#   baggage_cabin_not_included  flight_segments_count  flight_segment_ids  \
# 0                       True                      1              FR2255
# 1                       True                      1              FR1091
# 2                      False                      1              AZ1569
# 3                      False                      1              AZ1605
# 4                      False                      1              AZ1601
#
#               tim_itinerary  \
# 0  AHO-BGY-FR-2255-20260816
# 1  AHO-MXP-FR-1091-20260816
# 2  AHO-LIN-AZ-1569-20260816
# 3  AHO-LIN-AZ-1605-20260816
# 4  AHO-LIN-AZ-1601-20260816
#
#                                travelimpactmodel_url card_id  \
# 0  https://www.travelimpactmodel.org/lookup/fligh...  cMUkif
# 1  https://www.travelimpactmodel.org/lookup/fligh...  DLtkGf
# 2  https://www.travelimpactmodel.org/lookup/fligh...  HrPHOb
# 3  https://www.travelimpactmodel.org/lookup/fligh...   bhmT8
# 4  https://www.travelimpactmodel.org/lookup/fligh...  fRsXOe
#
#   airport_codes_found                                         query_text  \
# 0             AHO,BGY  Flights from AHO to MIL on 2026-08-16 oneway e...
# 1             AHO,MXP  Flights from AHO to MIL on 2026-08-16 oneway e...
# 2             AHO,LIN  Flights from AHO to MIL on 2026-08-16 oneway e...
# 3             AHO,LIN  Flights from AHO to MIL on 2026-08-16 oneway e...
# 4             AHO,LIN  Flights from AHO to MIL on 2026-08-16 oneway e...
#
#                                 flight_segments_json
# 0  [{"origin": "AHO", "destination": "BGY", "carr...
# 1  [{"origin": "AHO", "destination": "MXP", "carr...
# 2  [{"origin": "AHO", "destination": "LIN", "carr...
# 3  [{"origin": "AHO", "destination": "LIN", "carr...
# 4  [{"origin": "AHO", "destination": "LIN", "carr...
#
# [5 rows x 32 columns]
# -------------------------origin: Alghero destination: Milano target_date: 2026-08-23
# N. results: 5
#    result_index flight_id             flight_id_source              section  \
# 0             3    FR2255  travelimpactmodel_itinerary           Altri voli
# 1             0    FR1091  travelimpactmodel_itinerary  Voli più pertinenti
# 2             1    AZ1569  travelimpactmodel_itinerary  Voli più pertinenti
# 3             2    AZ1605  travelimpactmodel_itinerary  Voli più pertinenti
# 4             4    AZ1601  travelimpactmodel_itinerary           Altri voli
#
#    price_eur currency  airline operated_by carrier_code flight_number  \
# 0        196      EUR  Ryanair   Malta Air           FR          2255
# 1        225      EUR  Ryanair   Malta Air           FR          1091
# 2        230      EUR      ITA        None           AZ          1569
# 3        270      EUR      ITA        None           AZ          1605
# 4        315      EUR      ITA        None           AZ          1601
#
#   flight_departure_date origin destination depart_time arrive_time  ...  \
# 0            2026-08-23    AHO         BGY       07:35       08:50  ...
# 1            2026-08-23    AHO         MXP       17:35       18:50  ...
# 2            2026-08-23    AHO         LIN       07:00       08:10  ...
# 3            2026-08-23    AHO         LIN       08:55       10:05  ...
# 4            2026-08-23    AHO         LIN       20:55       22:05  ...
#
#   stops_count   origin_airport_name      destination_airport_name  \
# 0           0  Aeroporto di Alghero         Milan Bergamo Airport
# 1           0  Aeroporto di Alghero  Aeroporto di Milano Malpensa
# 2           0  Aeroporto di Alghero    Aeroporto di Milano Linate
# 3           0  Aeroporto di Alghero    Aeroporto di Milano Linate
# 4           0  Aeroporto di Alghero    Aeroporto di Milano Linate
#
#        depart_day_text      arrive_day_text emissions_kg_co2e  \
# 0  domenica, agosto 23  domenica, agosto 23              69.0
# 1  domenica, agosto 23  domenica, agosto 23              67.0
# 2  domenica, agosto 23  domenica, agosto 23              56.0
# 3  domenica, agosto 23  domenica, agosto 23              86.0
# 4  domenica, agosto 23  domenica, agosto 23              86.0
#
#   baggage_cabin_not_included  flight_segments_count  flight_segment_ids  \
# 0                       True                      1              FR2255
# 1                       True                      1              FR1091
# 2                      False                      1              AZ1569
# 3                      False                      1              AZ1605
# 4                      False                      1              AZ1601
#
#               tim_itinerary  \
# 0  AHO-BGY-FR-2255-20260823
# 1  AHO-MXP-FR-1091-20260823
# 2  AHO-LIN-AZ-1569-20260823
# 3  AHO-LIN-AZ-1605-20260823
# 4  AHO-LIN-AZ-1601-20260823
#
#                                travelimpactmodel_url card_id  \
# 0  https://www.travelimpactmodel.org/lookup/fligh...  PqFzEb
# 1  https://www.travelimpactmodel.org/lookup/fligh...  VL8ztb
# 2  https://www.travelimpactmodel.org/lookup/fligh...   AmjFu
# 3  https://www.travelimpactmodel.org/lookup/fligh...  kmSQse
# 4  https://www.travelimpactmodel.org/lookup/fligh...   eDZjk
#
#   airport_codes_found                                         query_text  \
# 0             AHO,BGY  Flights from AHO to MIL on 2026-08-23 oneway e...
# 1             AHO,MXP  Flights from AHO to MIL on 2026-08-23 oneway e...
# 2             AHO,LIN  Flights from AHO to MIL on 2026-08-23 oneway e...
# 3             AHO,LIN  Flights from AHO to MIL on 2026-08-23 oneway e...
# 4             AHO,LIN  Flights from AHO to MIL on 2026-08-23 oneway e...
#
#                                 flight_segments_json
# 0  [{"origin": "AHO", "destination": "BGY", "carr...
# 1  [{"origin": "AHO", "destination": "MXP", "carr...
# 2  [{"origin": "AHO", "destination": "LIN", "carr...
# 3  [{"origin": "AHO", "destination": "LIN", "carr...
# 4  [{"origin": "AHO", "destination": "LIN", "carr...
#
# [5 rows x 32 columns]
# -------------------------origin: Alghero destination: Milano target_date: 2026-08-30
# N. results: 5
#    result_index flight_id             flight_id_source              section  \
# 0             0    FR2255  travelimpactmodel_itinerary  Voli più pertinenti
# 1             1    AZ1569  travelimpactmodel_itinerary  Voli più pertinenti
# 2             2    AZ1605  travelimpactmodel_itinerary           Altri voli
# 3             3    AZ1601  travelimpactmodel_itinerary           Altri voli
# 4             4    FR1091  travelimpactmodel_itinerary           Altri voli
#
#    price_eur currency  airline operated_by carrier_code flight_number  \
# 0        111      EUR  Ryanair   Malta Air           FR          2255
# 1        164      EUR      ITA        None           AZ          1569
# 2        270      EUR      ITA        None           AZ          1605
# 3        270      EUR      ITA        None           AZ          1601
# 4        303      EUR  Ryanair   Malta Air           FR          1091
#
#   flight_departure_date origin destination depart_time arrive_time  ...  \
# 0            2026-08-30    AHO         BGY       07:35       08:50  ...
# 1            2026-08-30    AHO         LIN       07:00       08:10  ...
# 2            2026-08-30    AHO         LIN       08:55       10:05  ...
# 3            2026-08-30    AHO         LIN       20:55       22:05  ...
# 4            2026-08-30    AHO         MXP       17:35       18:50  ...
#
#   stops_count   origin_airport_name      destination_airport_name  \
# 0           0  Aeroporto di Alghero         Milan Bergamo Airport
# 1           0  Aeroporto di Alghero    Aeroporto di Milano Linate
# 2           0  Aeroporto di Alghero    Aeroporto di Milano Linate
# 3           0  Aeroporto di Alghero    Aeroporto di Milano Linate
# 4           0  Aeroporto di Alghero  Aeroporto di Milano Malpensa
#
#        depart_day_text      arrive_day_text emissions_kg_co2e  \
# 0  domenica, agosto 30  domenica, agosto 30              69.0
# 1  domenica, agosto 30  domenica, agosto 30              86.0
# 2  domenica, agosto 30  domenica, agosto 30              56.0
# 3  domenica, agosto 30  domenica, agosto 30              56.0
# 4  domenica, agosto 30  domenica, agosto 30              67.0
#
#   baggage_cabin_not_included  flight_segments_count  flight_segment_ids  \
# 0                       True                      1              FR2255
# 1                      False                      1              AZ1569
# 2                      False                      1              AZ1605
# 3                      False                      1              AZ1601
# 4                       True                      1              FR1091
#
#               tim_itinerary  \
# 0  AHO-BGY-FR-2255-20260830
# 1  AHO-LIN-AZ-1569-20260830
# 2  AHO-LIN-AZ-1605-20260830
# 3  AHO-LIN-AZ-1601-20260830
# 4  AHO-MXP-FR-1091-20260830
#
#                                travelimpactmodel_url card_id  \
# 0  https://www.travelimpactmodel.org/lookup/fligh...  TLOawc
# 1  https://www.travelimpactmodel.org/lookup/fligh...  Ngtfkf
# 2  https://www.travelimpactmodel.org/lookup/fligh...  nBjUJd
# 3  https://www.travelimpactmodel.org/lookup/fligh...  uRWJbb
# 4  https://www.travelimpactmodel.org/lookup/fligh...  XzWPhb
#
#   airport_codes_found                                         query_text  \
# 0             AHO,BGY  Flights from AHO to MIL on 2026-08-30 oneway e...
# 1             AHO,LIN  Flights from AHO to MIL on 2026-08-30 oneway e...
# 2             AHO,LIN  Flights from AHO to MIL on 2026-08-30 oneway e...
# 3             AHO,LIN  Flights from AHO to MIL on 2026-08-30 oneway e...
# 4             AHO,MXP  Flights from AHO to MIL on 2026-08-30 oneway e...
#
#                                 flight_segments_json
# 0  [{"origin": "AHO", "destination": "BGY", "carr...
# 1  [{"origin": "AHO", "destination": "LIN", "carr...
# 2  [{"origin": "AHO", "destination": "LIN", "carr...
# 3  [{"origin": "AHO", "destination": "LIN", "carr...
# 4  [{"origin": "AHO", "destination": "MXP", "carr...
#
# [5 rows x 32 columns]
# -------------------------origin: Alghero destination: Roma target_date: 2026-08-09
# N. results: 5
#    result_index flight_id             flight_id_source              section  \
# 0             0    XZ2510  travelimpactmodel_itinerary  Voli più pertinenti
# 1             1    XZ2512  travelimpactmodel_itinerary           Altri voli
# 2             2    XZ2518  travelimpactmodel_itinerary           Altri voli
# 3             3    XZ2514  travelimpactmodel_itinerary           Altri voli
# 4             4    XZ2516  travelimpactmodel_itinerary           Altri voli
#
#    price_eur currency     airline operated_by carrier_code flight_number  \
# 0         80      EUR  Aeroitalia        None           XZ          2510
# 1         90      EUR  Aeroitalia        None           XZ          2512
# 2         95      EUR  Aeroitalia        None           XZ          2518
# 3        100      EUR  Aeroitalia        None           XZ          2514
# 4        105      EUR  Aeroitalia        None           XZ          2516
#
#   flight_departure_date origin destination depart_time arrive_time  ...  \
# 0            2026-08-09    AHO         FCO       06:10       07:10  ...
# 1            2026-08-09    AHO         FCO       09:40       10:40  ...
# 2            2026-08-09    AHO         FCO       20:10       21:10  ...
# 3            2026-08-09    AHO         FCO       12:40       13:40  ...
# 4            2026-08-09    AHO         FCO       16:40       17:40  ...
#
#   stops_count   origin_airport_name  \
# 0           0  Aeroporto di Alghero
# 1           0  Aeroporto di Alghero
# 2           0  Aeroporto di Alghero
# 3           0  Aeroporto di Alghero
# 4           0  Aeroporto di Alghero
#
#                           destination_airport_name     depart_day_text  \
# 0  Aeroporto di Roma - Fiumicino Leonardo da Vinci  domenica, agosto 9
# 1  Aeroporto di Roma - Fiumicino Leonardo da Vinci  domenica, agosto 9
# 2  Aeroporto di Roma - Fiumicino Leonardo da Vinci  domenica, agosto 9
# 3  Aeroporto di Roma - Fiumicino Leonardo da Vinci  domenica, agosto 9
# 4  Aeroporto di Roma - Fiumicino Leonardo da Vinci  domenica, agosto 9
#
#       arrive_day_text emissions_kg_co2e baggage_cabin_not_included  \
# 0  domenica, agosto 9              52.0                      False
# 1  domenica, agosto 9              52.0                      False
# 2  domenica, agosto 9              52.0                      False
# 3  domenica, agosto 9              52.0                      False
# 4  domenica, agosto 9              52.0                      False
#
#    flight_segments_count  flight_segment_ids             tim_itinerary  \
# 0                      1              XZ2510  AHO-FCO-XZ-2510-20260809
# 1                      1              XZ2512  AHO-FCO-XZ-2512-20260809
# 2                      1              XZ2518  AHO-FCO-XZ-2518-20260809
# 3                      1              XZ2514  AHO-FCO-XZ-2514-20260809
# 4                      1              XZ2516  AHO-FCO-XZ-2516-20260809
#
#                                travelimpactmodel_url card_id  \
# 0  https://www.travelimpactmodel.org/lookup/fligh...  aZgOpe
# 1  https://www.travelimpactmodel.org/lookup/fligh...  Lt2IAe
# 2  https://www.travelimpactmodel.org/lookup/fligh...   H5BMf
# 3  https://www.travelimpactmodel.org/lookup/fligh...  u3wSZd
# 4  https://www.travelimpactmodel.org/lookup/fligh...  FhTNTe
#
#   airport_codes_found                                         query_text  \
# 0             AHO,FCO  Flights from AHO to ROM on 2026-08-09 oneway e...
# 1             AHO,FCO  Flights from AHO to ROM on 2026-08-09 oneway e...
# 2             AHO,FCO  Flights from AHO to ROM on 2026-08-09 oneway e...
# 3             AHO,FCO  Flights from AHO to ROM on 2026-08-09 oneway e...
# 4             AHO,FCO  Flights from AHO to ROM on 2026-08-09 oneway e...
#
#                                 flight_segments_json
# 0  [{"origin": "AHO", "destination": "FCO", "carr...
# 1  [{"origin": "AHO", "destination": "FCO", "carr...
# 2  [{"origin": "AHO", "destination": "FCO", "carr...
# 3  [{"origin": "AHO", "destination": "FCO", "carr...
# 4  [{"origin": "AHO", "destination": "FCO", "carr...
#
# [5 rows x 32 columns]
